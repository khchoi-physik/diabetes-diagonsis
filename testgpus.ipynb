# %%
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Fri_Jun_14_16:34:21_PDT_2024
# Cuda compilation tools, release 12.6, V12.6.20
# Build cuda_12.6.r12.6/compiler.34431801_0


#nvidia-smi

# %%
import cupy as cp; print(cp.__version__)
import xgboost as xgb; print(xgb.__version__)
import lightgbm as lg; print(lg.__version__)
import cudf; print(cudf.__version__)
# Out:
# 13.6.0
# 3.1.2
# 4.6.0
# 25.12.00

# %%
print("hello")
# Out:
# hello

# %%
import cupy as cp
random_matrix = cp.random.rand(3, 3)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cuda.version()
#
# NameError: name 'cuda' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 nvidia-smi
#
# NameError: name 'nvidia' is not defined
